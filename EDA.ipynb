# %%
import pandas as pd

penetracion = pd.read_csv("Internet_Penetracion.csv", decimal=',')

display(penetracion.head(10))
penetracion.info()
# Out:
#     Año  Trimestre        Provincia  Accesos por cada 100 hogares
# 0  2022          2     Buenos Aires                         77.58
# 1  2022          2  Capital Federal                        121.31
# 2  2022          2        Catamarca                         62.40
# 3  2022          2            Chaco                         43.79
# 4  2022          2           Chubut                         83.19
# 5  2022          2          Córdoba                         87.48
# 6  2022          2       Corrientes                         48.35
# 7  2022          2       Entre Ríos                         63.90
# 8  2022          2          Formosa                         43.42
# 9  2022          2            Jujuy                         57.32
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 4 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
# ...

# %%
penetracion['Accesos por cada 100 hogares'].max()
# Out:
# 124.06

# %% [markdown]
# En este dataset tenemos el histórico trimestral de la cantidad de accessos por cada 100 hogares, desglozado por provincia. Tenemos 816 registros desde 2014 hasta 2021. Uno de los objetivos de este proyecto es evaluar el aumento o disminución de la variación porcentual trimestral del servicio de internet, cada 100 hogares por provincia y este dataset tiene toda la informacion que necesitamos para cumplir este objetivo.

# %%
conectividad =pd.read_csv("ConectividadalserviciodeInternet_2776151672760470518.csv")

conectividad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4312 entries, 0 to 4311
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Provincia      4312 non-null   object
#  1   Partido        4312 non-null   object
#  2   Localidad      4312 non-null   object
#  3   Poblacion      4312 non-null   int64
#  4   ADSL           4312 non-null   object
#  5   CABLEMODEM     4312 non-null   object
#  6   DIALUP         4312 non-null   object
#  7   FIBRAOPTICA    4312 non-null   object
#  8   SATELITAL      4312 non-null   object
#  9   WIRELESS       4312 non-null   object
#  10  TELEFONIAFIJA  4312 non-null   object
#  11  3G             4312 non-null   object
#  12  4G             4312 non-null   object
#  13  link           3836 non-null   float64
#  14  Latitud        4312 non-null   float64
#  15  Longitud       4312 non-null   float64
# dtypes: float64(3), int64(1), object(12)
# memory usage: 539.1+ KB

# %% [markdown]
# En este data set tenemos el desgloce de conexiones a internet disponibles por partido y localidad, desglosado en el tipo de conexion. Tambien tenemos la poblacion de cada localidad, de aqui podemos extraer informacion como que porcentage de la poblacion tiene acceso a internet. Tenemos 4312 registros, de todas las localidades del pais.

# %%
conectividad[(conectividad['ADSL'] == '--') & (conectividad['CABLEMODEM'] == '--') & (conectividad['DIALUP'] == '--' )& (conectividad['FIBRAOPTICA'] == '--') & 
    (conectividad['SATELITAL'] == '--') & (conectividad['WIRELESS'] == '--') & (conectividad['3G'] == '--') & (conectividad['4G'] == '--')]
# Out:
#          Provincia                 Partido           Localidad  Poblacion  \
# 1     BUENOS AIRES              25 de Mayo     Agustín Mosconi        280
# 8     BUENOS AIRES              25 de Mayo         San Enrique        279
# 13    BUENOS AIRES          Carlos Tejedor              Curarú        422
# 14    BUENOS AIRES          Carlos Tejedor              Timote        526
# 28    BUENOS AIRES       General La Madrid           La Colina        663
# ...            ...                     ...                 ...        ...
# 4285       FORMOSA                 Bermejo         Guadalcazar        146
# 4298         JUJUY  Doctor Manuel Belgrano             Ocloyas         70
# 4299         JUJUY  Doctor Manuel Belgrano  San Pablo De Reyes          0
# 4303         JUJUY               El Carmen   Barrio El Milagro       1321
# 4304         JUJUY               El Carmen     Barrio La Unión        700
#
#      ADSL CABLEMODEM DIALUP FIBRAOPTICA SATELITAL WIRELESS TELEFONIAFIJA  3G  \
# ...

# %% [markdown]
# Aqui podemos evidenciar que efectivamente hay 904 localidades que no tienen acceso a internet

# %%
conectividad[(conectividad['Poblacion'] == 0)]
# Out:
#          Provincia                 Partido                Localidad  \
# 35    BUENOS AIRES       General Las Heras                   Lozano
# 38    BUENOS AIRES         General Lavalle  Chacras de San Clemente
# 42    BUENOS AIRES                La Plata           La Providencia
# 43    BUENOS AIRES                La Plata           Lisandro Olmos
# 45    BUENOS AIRES                La Plata               Los Hornos
# ...            ...                     ...                      ...
# 4238       CORDOBA              San Javier              Los Romeros
# 4253  BUENOS AIRES  General Juan Madariaga           Barrio Kennedy
# 4268       FORMOSA                 Formosa           Villa Trinidad
# 4299         JUJUY  Doctor Manuel Belgrano       San Pablo De Reyes
# 4306         JUJUY               El Carmen                  Fleming
#
#       Poblacion ADSL CABLEMODEM DIALUP FIBRAOPTICA SATELITAL WIRELESS  \
# 35            0   --         --     --          --        SI       --
# ...

# %%
conectividad[(conectividad['Poblacion'] == 0) & (conectividad['ADSL'] == '--') & (conectividad['CABLEMODEM'] == '--') & (conectividad['DIALUP'] == '--' )& (conectividad['FIBRAOPTICA'] == '--') & 
    (conectividad['SATELITAL'] == '--') & (conectividad['WIRELESS'] == '--') & (conectividad['3G'] == '--') & (conectividad['4G'] == '--')]
# Out:
#          Provincia                     Partido                Localidad  \
# 42    BUENOS AIRES                    La Plata           La Providencia
# 47    BUENOS AIRES                    La Plata                   Poblet
# 127       SAN LUIS  Libertador Grl. San Martín         Planta De Sandia
# 153        CORDOBA                 Santa María  Barrio Villa del Parque
# 186   BUENOS AIRES               Adolfo Alsina                   Thames
# ...            ...                         ...                      ...
# 4218       MENDOZA               Luján de Cuyo         Villa El Refugio
# 4226       CORDOBA                  San Javier              El Pueblito
# 4227       CORDOBA                  San Javier                 El Valle
# 4268       FORMOSA                     Formosa           Villa Trinidad
# 4299         JUJUY      Doctor Manuel Belgrano       San Pablo De Reyes
#
#       Poblacion ADSL CABLEMODEM DIALUP FIBRAOPTICA SATELITAL WIRELESS  \
# ...

# %% [markdown]
# Aqui podemos evidenciar que tenemos 267 filas que tienen poblacion 0 y que no reportan acceso a internet. Se debe tener en cuenta en el analisis esta información faltante.

# %%
velocidad = pd.read_csv("historico_velocidad_internet.csv")

display(velocidad.head())
velocidad.info()
# Out:
#     Año  Trimestre        Provincia  Mbps (Media de bajada)
# 0  2022          2     Buenos Aires                      66
# 1  2022          2  Capital Federal                      94
# 2  2022          2        Catamarca                      57
# 3  2022          2            Chaco                      51
# 4  2022          2           Chubut                      15
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Año                     816 non-null    int64
#  1   Trimestre               816 non-null    int64
#  2   Provincia               816 non-null    object
#  3   Mbps (Media de bajada)  816 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 25.6+ KB

# %% [markdown]
# En este dataset tenemos el historico trimestral de la velocidad promedio de bajada de internet, desglozada por provincia. Con este dataset podemos encontrar la variación con el tiempo y tambien usar la información de la media para descubrir otros datos.

# %%
ingresos = pd.read_csv("Internet_Ingresos.csv")

display(ingresos.head())
ingresos.info()
# Out:
#     Año  Trimestre Ingresos (miles de pesos)        Periodo
# 0  2022          2                60.942.843   Abr-Jun 2022
# 1  2022          1                56.195.811   Ene-Mar 2022
# 2  2021          4                45.467.887   Oct-Dic 2021
# 3  2021          3                42.999.944  Jul-Sept 2021
# 4  2021          2                38.239.667   Abr-Jun 2021
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 4 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Año                        34 non-null     int64
#  1   Trimestre                  34 non-null     int64
#  2   Ingresos (miles de pesos)  34 non-null     object
#  3   Periodo                    34 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 1.2+ KB

# %% [markdown]
# En este dataset tenemos el histórico trimestral de los ingresos por la prestación del servicio de internet fijo. Con esta información podemos ver el cambio histórico de ingresos y teniendo en cuenta la cantidad de accesos y el precio, podemos conocer el precio promedio de un Mbps de forma histórica.

# %%
accessos = pd.read_csv("Internet_Accesos-por-velocidad.csv")

display(accessos.head())
accessos.info()
# Out:
#     Año  Trimestre        Provincia  HASTA 512 kbps  + 512 Kbps - 1 Mbps  \
# 0  2022          2     Buenos Aires          30.639               28.323
# 1  2022          2  Capital Federal         517.000                5.980
# 2  2022          2        Catamarca          71.000              413.000
# 3  2022          2            Chaco         461.000                1.047
# 4  2022          2           Chubut         109.000                1.444
#
#   + 1 Mbps - 6 Mbps  + 6 Mbps - 10 Mbps  + 10 Mbps - 20 Mbps  \
# 0           295.238             307.554              273.954
# 1            36.036              72.434               55.372
# 2             3.678               6.155                7.165
# 3            17.603              20.109                8.391
# 4            45.804              31.217               34.290
#
#    + 20 Mbps - 30 Mbps  + 30 Mbps    OTROS      Total
# 0              129.869  3.535.757   65.849  4.667.183
# ...

# %% [markdown]
# De este dataset podemos conocer la cantidad de conexiones por velocidad de conexion en cada region de forma historica. De esta información podemos usar el total de conexiones para determinar, junto con el promedio de descarga, la capacidad total instalada en Mbps. Con esto y el ingreso, podemos determinar el costo por Mbps historico.
#
# Tambien podemos conocer la moda de la velocidad de conexion, que en este caso es relevante pues el promedio no nos da toda la información sobre los tipos de conexion instaladas.
